# %%
import pandas as pd
import datetime

# %%
df = pd.read_csv('../datasets/nobel.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/irenecaceres/Desktop/git_course/Scripts/numpy_pandas_scipy/06_pandas_nobel_exercise.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell:/Users/irenecaceres/Desktop/git_course/Scripts/numpy_pandas_scipy/06_pandas_nobel_exercise.ipynb#ch0000001?line=0'>1</a> df = pd.read_csv('../datasets/nobel.csv')
#       <a href='vscode-notebook-cell:/Users/irenecaceres/Desktop/git_course/Scripts/numpy_pandas_scipy/06_pandas_nobel_exercise.ipynb#ch0000001?line=1'>2</a> df.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=571'>572</a> _validate_names(kwds.get("names", None))
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=573'>574</a> # Create the parser.
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=574'>575</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=576'>577</a> if chunksize or iterator:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=929'>930</a>     self.options["has_index_names"] = kwds["has_index_names"]
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=931'>932</a> self.handles: IOHandles | None = None
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=932'>933</a> self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1212'>1213</a>     mode = "rb"
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1213'>1214</a> # error: No overload variant of "get_handle" matches argument types
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1214'>1215</a> # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1215'>1216</a> # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1216'>1217</a> self.handles = get_handle(  # type: ignore[call-overload]
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1217'>1218</a>     f,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1218'>1219</a>     mode,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1219'>1220</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1220'>1221</a>     compression=self.options.get("compression", None),
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1221'>1222</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1222'>1223</a>     is_text=is_text,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1223'>1224</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1224'>1225</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1225'>1226</a> )
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1226'>1227</a> assert self.handles is not None
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py?line=1227'>1228</a> f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=783'>784</a> elif isinstance(handle, str):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=784'>785</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=785'>786</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=786'>787</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=787'>788</a>         # Encoding
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=788'>789</a>         handle = open(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=789'>790</a>             handle,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=790'>791</a>             ioargs.mode,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=791'>792</a>             encoding=ioargs.encoding,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=792'>793</a>             errors=errors,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=793'>794</a>             newline="",
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=794'>795</a>         )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=795'>796</a>     else:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=796'>797</a>         # Binary mode
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=797'>798</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../datasets/nobel.csv'

# %% [markdown]
# (1) In which years was there a price related to refugees?

# %%
df[df.motivation.str.contains('refugee')][['awardYear','category']]
# Out:
#      awardYear category
# 267       1922    Peace
# 303       1958    Peace
# 615       1938    Peace
# 634       1954    Peace
# 948       1981    Peace

# %% [markdown]
# (2) In all categories there have been more men than women winners. In which category is the gap the largest (in absolute values)? And in percentage?

# %%
df.gender.isna().sum()
# Out:
# 27

# %%
df.groupby(['category','gender'],dropna=False).size()
# Out:
# category                gender
# Chemistry               female      5
#                         male      179
# Economic Sciences       female      2
#                         male       82
# Literature              female     15
#                         male      101
# Peace                   female     17
#                         male       90
#                         NaN        27
# Physics                 female      3
#                         male      210
# Physiology or Medicine  female     12
#                         male      207
# dtype: int64

# %%
grouped = df.groupby(['category','gender'],dropna=False).size().\
    reset_index(name = 'count')
grouped.head()
# Out:
#             category  gender  count
# 0          Chemistry  female      5
# 1          Chemistry    male    179
# 2  Economic Sciences  female      2
# 3  Economic Sciences    male     82
# 4         Literature  female     15

# %% [markdown]
# ---- Método (I) ----

# %%
def dif_f_m(df_in, ret = "dif_abs"):
    '''
    For a given category, extract difference of male - female awardees.
    
    Parameters
    ------------
    df_in: (DataFrame) DataFrame containing a 'gender' column (male, female, NA)
    and a 'count' column, with the number of awardees per gender.
    
    ret: (str) controla the output
    
    Returns
    ------------
    If ret == "dif_abs": (int) Absolute difference in magnitude
    
    Si ret == "dif_porc": (float) Difference in percentage
    '''
    f = df_in[df_in['gender'] == "female"]['count'].item()
    m = df_in[df_in['gender'] == "male"]['count'].item()
    tot = df_in['count'].sum()
    if(ret == "dif_abs"):
        return m-f
    elif(ret =="dif_porc"):
        return 100*(m-f)/tot
    else:
        return None

# %%
grouped
# Out:
#                   category  gender  count
# 0                Chemistry  female      5
# 1                Chemistry    male    179
# 2        Economic Sciences  female      2
# 3        Economic Sciences    male     82
# 4               Literature  female     15
# 5               Literature    male    101
# 6                    Peace  female     17
# 7                    Peace    male     90
# 8                    Peace     NaN     27
# 9                  Physics  female      3
# 10                 Physics    male    210
# 11  Physiology or Medicine  female     12
# 12  Physiology or Medicine    male    207

# %%
dif_m_f = grouped.groupby('category').\
    apply(lambda x: dif_f_m(x)).\
    reset_index(name ="abs_dif_m_f")
dif_m_f
# Out:
#                  category  abs_dif_m_f
# 0               Chemistry          174
# 1       Economic Sciences           80
# 2              Literature           86
# 3                   Peace           73
# 4                 Physics          207
# 5  Physiology or Medicine          195

# %%
grouped.groupby('category').apply(lambda x: dif_f_m(x, ret = "dif_porc"))
# Out:
# category
# Chemistry                 94.565217
# Economic Sciences         95.238095
# Literature                74.137931
# Peace                     54.477612
# Physics                   97.183099
# Physiology or Medicine    89.041096
# dtype: float64

# %%
dif_m_f['porc_dif_m_f'] = grouped.groupby('category').apply(lambda x: dif_f_m(x, ret = "dif_porc")).values
dif_m_f
# Out:
#                  category  abs_dif_m_f  porc_dif_m_f
# 0               Chemistry          174     94.565217
# 1       Economic Sciences           80     95.238095
# 2              Literature           86     74.137931
# 3                   Peace           73     54.477612
# 4                 Physics          207     97.183099
# 5  Physiology or Medicine          195     89.041096

# %% [markdown]
# ---- Método (II) ----

# %%
piv = grouped.pivot(index="category", columns="gender", values="count")
display(piv)
# Out:
# gender                   NaN  female   male
# category
# Chemistry                NaN     5.0  179.0
# Economic Sciences        NaN     2.0   82.0
# Literature               NaN    15.0  101.0
# Peace                   27.0    17.0   90.0
# Physics                  NaN     3.0  210.0
# Physiology or Medicine   NaN    12.0  207.0

# %%
piv.rename(columns={ piv.columns[0]: "not_assigned" }, inplace = True)
display(piv)
# Out:
# gender                  not_assigned  female   male
# category
# Chemistry                        NaN     5.0  179.0
# Economic Sciences                NaN     2.0   82.0
# Literature                       NaN    15.0  101.0
# Peace                           27.0    17.0   90.0
# Physics                          NaN     3.0  210.0
# Physiology or Medicine           NaN    12.0  207.0

# %%
piv['total'] = piv.sum(axis=1, skipna = True)
piv['abs_dif_m_f'] = piv.male - piv.female
display(piv)
# Out:
# gender                  not_assigned  female   male  total  abs_dif_m_f
# category
# Chemistry                        NaN     5.0  179.0  184.0        174.0
# Economic Sciences                NaN     2.0   82.0   84.0         80.0
# Literature                       NaN    15.0  101.0  116.0         86.0
# Peace                           27.0    17.0   90.0  134.0         73.0
# Physics                          NaN     3.0  210.0  213.0        207.0
# Physiology or Medicine           NaN    12.0  207.0  219.0        195.0

# %%
piv['porc_dif_m_f'] = 100*piv.abs_dif_m_f/piv.total
display(piv)
# Out:
# gender                  not_assigned  female   male  total  abs_dif_m_f  \
# category
# Chemistry                        NaN     5.0  179.0  184.0        174.0
# Economic Sciences                NaN     2.0   82.0   84.0         80.0
# Literature                       NaN    15.0  101.0  116.0         86.0
# Peace                           27.0    17.0   90.0  134.0         73.0
# Physics                          NaN     3.0  210.0  213.0        207.0
# Physiology or Medicine           NaN    12.0  207.0  219.0        195.0
#
# gender                  porc_dif_m_f
# category
# Chemistry                  94.565217
# Economic Sciences          95.238095
# Literature                 74.137931
# Peace                      54.477612
# Physics                    97.183099
# Physiology or Medicine     89.041096

# %% [markdown]
# --- Comparación métodos ---

# %%
piv.sort_values('abs_dif_m_f', ascending = False)
# Out:
# gender                  not_assigned  female   male  total  abs_dif_m_f  \
# category
# Physics                          NaN     3.0  210.0  213.0        207.0
# Physiology or Medicine           NaN    12.0  207.0  219.0        195.0
# Chemistry                        NaN     5.0  179.0  184.0        174.0
# Literature                       NaN    15.0  101.0  116.0         86.0
# Economic Sciences                NaN     2.0   82.0   84.0         80.0
# Peace                           27.0    17.0   90.0  134.0         73.0
#
# gender                  porc_dif_m_f
# category
# Physics                    97.183099
# Physiology or Medicine     89.041096
# Chemistry                  94.565217
# Literature                 74.137931
# Economic Sciences          95.238095
# Peace                      54.477612

# %%
dif_m_f.sort_values('abs_dif_m_f', ascending = False)
# Out:
#                  category  abs_dif_m_f  porc_dif_m_f
# 4                 Physics          207     97.183099
# 5  Physiology or Medicine          195     89.041096
# 0               Chemistry          174     94.565217
# 2              Literature           86     74.137931
# 1       Economic Sciences           80     95.238095
# 3                   Peace           73     54.477612

# %%
piv.sort_values('porc_dif_m_f', ascending = False)
# Out:
# gender                  not_assigned  female   male  total  abs_dif_m_f  \
# category
# Physics                          NaN     3.0  210.0  213.0        207.0
# Economic Sciences                NaN     2.0   82.0   84.0         80.0
# Chemistry                        NaN     5.0  179.0  184.0        174.0
# Physiology or Medicine           NaN    12.0  207.0  219.0        195.0
# Literature                       NaN    15.0  101.0  116.0         86.0
# Peace                           27.0    17.0   90.0  134.0         73.0
#
# gender                  porc_dif_m_f
# category
# Physics                    97.183099
# Economic Sciences          95.238095
# Chemistry                  94.565217
# Physiology or Medicine     89.041096
# Literature                 74.137931
# Peace                      54.477612

# %%
dif_m_f.sort_values('porc_dif_m_f', ascending = False)
# Out:
#                  category  abs_dif_m_f  porc_dif_m_f
# 4                 Physics          207     97.183099
# 1       Economic Sciences           80     95.238095
# 0               Chemistry          174     94.565217
# 5  Physiology or Medicine          195     89.041096
# 2              Literature           86     74.137931
# 3                   Peace           73     54.477612

# %% [markdown]
# (3)

# %% [markdown]
# (a)

# %%
df.awardYear.min()
# Out:
# 1901

# %%
begin_category = df.groupby('category')['awardYear'].min().reset_index()
begin_category
# Out:
#                  category  awardYear
# 0               Chemistry       1901
# 1       Economic Sciences       1969
# 2              Literature       1901
# 3                   Peace       1901
# 4                 Physics       1901
# 5  Physiology or Medicine       1901

# %%
begin_category[begin_category.awardYear > df.awardYear.min()].category
# Out:
# 1    Economic Sciences
# Name: category, dtype: object

# %% [markdown]
# (4)

# %%
df.dtypes
# Out:
# awardYear                      int64
# category                      object
# categoryFullName              object
# sortOrder                      int64
# portion                       object
# prizeAmount                    int64
# prizeAmountAdjusted            int64
# dateAwarded                   object
# prizeStatus                   object
# motivation                    object
# categoryTopMotivation         object
# award_link                    object
# id                             int64
# name                          object
# knownName                     object
# givenName                     object
# familyName                    object
# fullName                      object
# penName                       object
# gender                        object
# laureate_link                 object
# birth_date                    object
# birth_city                    object
# birth_cityNow                 object
# birth_continent               object
# birth_country                 object
# birth_countryNow              object
# birth_locationString          object
# death_date                    object
# death_city                    object
# death_cityNow                 object
# death_continent               object
# death_country                 object
# death_countryNow              object
# death_locationString          object
# orgName                       object
# nativeName                    object
# acronym                       object
# org_founded_date              object
# org_founded_city              object
# org_founded_cityNow           object
# org_founded_continent         object
# org_founded_country           object
# org_founded_countryNow        object
# org_founded_locationString    object
# ind_or_org                    object
# residence_1                   object
# residence_2                   object
# affiliation_1                 object
# affiliation_2                 object
# affiliation_3                 object
# affiliation_4                 object
# dtype: object

# %%
(df.birth_countryNow == 'Austria').sum() #
# Out:
# 18

# %%
df[df.birth_countryNow == 'Austria'].birth_country
# Out:
# 36             Austria
# 201            Austria
# 218            Austria
# 230            Austria
# 269            Austria
# 497            Austria
# 502    Austrian Empire
# 503            Austria
# 520            Austria
# 572            Austria
# 585            Austria
# 683            Austria
# 719    Austria-Hungary
# 726    Austrian Empire
# 733            Austria
# 884            Austria
# 892            Austria
# 933            Austria
# Name: birth_country, dtype: object

# %%
df[df.birth_date.str[5:7] == '00']
# Out:
#      awardYear           category  \
# 0         2001  Economic Sciences
# 26        1960              Peace
# 612       2018              Peace
# 670       2018  Economic Sciences
# 785       2011            Physics
# 880       2009          Chemistry
#
#                                       categoryFullName  sortOrder portion  \
# 0    The Sveriges Riksbank Prize in Economic Scienc...          2     1/3
# 26                               The Nobel Peace Prize          1       1
# 612                              The Nobel Peace Prize          2     1/2
# 670  The Sveriges Riksbank Prize in Economic Scienc...          2     1/2
# 785                         The Nobel Prize in Physics          1     1/2
# 880                       The Nobel Prize in Chemistry          1     1/3
#
#      prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 0       10000000             12295082  2001-10-10    received
# 26        225987              2664941  1961-10-23    received
# 612      9000000              9000000  2018-10-05    received
# 670      9000000              9000000         NaN    received
# 785     10000000             10545557  2011-10-04    received
# 880     10000000             10958504  2009-10-07    received
#
#                                             motivation  ...  \
# 0    for their analyses of markets with asymmetric ...  ...
# 26      for his non-violent struggle against apartheid  ...
# 612  for their efforts to end the use of sexual vio...  ...
# 670  for integrating technological innovations into...  ...
# 785  for the discovery of the accelerating expansio...  ...
# 880  for studies of the structure and function of t...  ...
#
#     org_founded_country org_founded_countryNow  org_founded_locationString  \
# 0                   NaN                    NaN                         NaN
# 26                  NaN                    NaN                         NaN
# 612                 NaN                    NaN                         NaN
# 670                 NaN                    NaN                         NaN
# 785                 NaN                    NaN                         NaN
# 880                 NaN                    NaN                         NaN
#
#      ind_or_org   residence_1 residence_2  \
# 0    Individual           NaN         NaN
# 26   Individual  South Africa         NaN
# 612  Individual           NaN         NaN
# 670  Individual           NaN         NaN
# 785  Individual           NaN         NaN
# 880  Individual           NaN         NaN
#
#                                          affiliation_1  \
# 0               Stanford University, Stanford, CA, USA
# 26                                                 NaN
# 612                                                NaN
# 670    NYU Stern School of Business, New York, NY, USA
# 785  Lawrence Berkeley National Laboratory, Berkele...
# 880  MRC Laboratory of Molecular Biology, Cambridge...
#
#                                    affiliation_2 affiliation_3 affiliation_4
# 0                                            NaN           NaN           NaN
# 26                                           NaN           NaN           NaN
# 612                                          NaN           NaN           NaN
# 670                                          NaN           NaN           NaN
# 785  University of California, Berkeley, CA, USA           NaN           NaN
# 880                                          NaN           NaN           NaN
#
# [6 rows x 52 columns]

# %%
pd.to_datetime(df.birth_date)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\_libs\tslib.pyx:536, in pandas._libs.tslib.array_to_datetime()
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\dateutil\parser\_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: month must be in 1..12: 1943-00-00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\_libs\tslib.pyx:547, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Input In [110], in <cell line: 1>()
# ----> 1 pd.to_datetime(df.birth_date)
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\core\tools\datetimes.py:1051, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049         result = arg.map(cache_array)
#    1050     else:
# -> 1051         values = convert_listlike(arg._values, format)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\core\tools\datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\core\arrays\datetimes.py:2217, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2215         return values.view("i8"), tz_parsed
#    2216     except (ValueError, TypeError):
# -> 2217         raise err
#    2219 if tz_parsed is not None:
#    2220     # We can take a shortcut since the datetime64 numpy array
#    2221     #  is in UTC
#    2222     # Return i8 values to denote unix timestamps
#    2223     return result.view("i8"), tz_parsed
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\core\arrays\datetimes.py:2199, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2197 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2198 try:
# -> 2199     result, tz_parsed = tslib.array_to_datetime(
#    2200         data.ravel("K"),
#    2201         errors=errors,
#    2202         utc=utc,
#    2203         dayfirst=dayfirst,
#    2204         yearfirst=yearfirst,
#    2205         require_iso8601=require_iso8601,
#    2206         allow_mixed=allow_mixed,
#    2207     )
#    2208     result = result.reshape(data.shape, order=order)
#    2209 except ValueError as err:
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\_libs\tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\_libs\tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\_libs\tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\_libs\tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File c:\users\priego\pycharmprojects\01-intropython\venv\lib\site-packages\dateutil\parser\_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: month must be in 1..12: 1943-00-00

# %%
df['birth_date'] = df.birth_date.str.replace('00','01')

# %%
df['bd'] = pd.to_datetime(df.birth_date)

# %%
df['bd'].dt.year
# Out:
# 0      1943.0
# 1      1922.0
# 2      1947.0
# 3      1926.0
# 4      1926.0
#         ...
# 945    1908.0
# 946    1901.0
# 947    1867.0
# 948       NaN
# 949       NaN
# Name: bd, Length: 950, dtype: float64

# %%
df['age_awarded'] = df.awardYear - df.bd.dt.year

# %%
df[df.birth_countryNow == 'Austria'].\
    sort_values('age_awarded', ascending = False)\
[['category','awardYear','age_awarded','name']]
# Out:
#                    category  awardYear  age_awarded                   name
# 503  Physiology or Medicine       1973         87.0        Karl von Frisch
# 572               Chemistry       2013         83.0         Martin Karplus
# 683              Literature       2019         77.0           Peter Handke
# 892               Chemistry       1998         75.0            Walter Kohn
# 269       Economic Sciences       1974         75.0    Friedrich von Hayek
# 218  Physiology or Medicine       2000         71.0            Eric Kandel
# 497  Physiology or Medicine       1927         70.0  Julius Wagner-Jauregg
# 520  Physiology or Medicine       1973         70.0          Konrad Lorenz
# 502  Physiology or Medicine       1930         62.0       Karl Landsteiner
# 726               Chemistry       1925         60.0      Richard Zsigmondy
# 201              Literature       2004         58.0       Elfriede Jelinek
# 884                 Physics       1936         53.0         Victor F. Hess
# 585               Chemistry       1962         48.0          Max F. Perutz
# 36                    Peace       1911         47.0           Alfred Fried
# 230                 Physics       1933         46.0      Erwin Schrödinger
# 933                 Physics       1945         44.0         Wolfgang Pauli
# 733  Physiology or Medicine       1914         38.0          Robert Bárány
# 719               Chemistry       1938         37.0           Richard Kuhn

# %%
df[df.birth_countryNow == 'Austria'].sort_values('age_awarded', ascending = False)\
.iloc[0]['name']
# Out:
# 'Karl von Frisch'

# %% [markdown]
# (5)

# %%
df[df.birth_countryNow == "Spain"].shape[0]
# Out:
# 7

# %% [markdown]
# (6)

# %%
current_year = datetime.datetime.now().year

# %%
spanish = df[df.birth_countryNow == "Spain"]
spanish
# Out:
#      awardYear                category  \
# 111       1989              Literature
# 411       1922              Literature
# 480       1904              Literature
# 492       1956              Literature
# 782       1906  Physiology or Medicine
# 791       1959  Physiology or Medicine
# 883       1977              Literature
#
#                               categoryFullName  sortOrder portion  \
# 111             The Nobel Prize in  Literature          1       1
# 411             The Nobel Prize in  Literature          1       1
# 480             The Nobel Prize in  Literature          2     1/2
# 492             The Nobel Prize in  Literature          1       1
# 782  The Nobel Prize in Physiology or Medicine          2     1/2
# 791  The Nobel Prize in Physiology or Medicine          1     1/2
# 883             The Nobel Prize in  Literature          1       1
#
#      prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 111      3000000              5242311         NaN    received
# 411       122483              3145967         NaN    received
# 480       140859              7767960         NaN    received
# 492       200123              2699501         NaN    received
# 782       138536              7421571         NaN    received
# 791       220678              2704387         NaN    received
# 883       700000              3080986         NaN    received
#
#                                             motivation  ...  \
# 111  for a rich and intensive prose, which with res...  ...
# 411  for the happy manner in which he has continued...  ...
# 480  in recognition of the numerous and brilliant c...  ...
# 492  for his lyrical poetry, which in Spanish langu...  ...
# 782  in recognition of their work on the structure ...  ...
# 791  for their discovery of the mechanisms in the b...  ...
# 883  for a creative poetic writing which illuminate...  ...
#
#     org_founded_locationString  ind_or_org  residence_1 residence_2  \
# 111                        NaN  Individual        Spain         NaN
# 411                        NaN  Individual        Spain         NaN
# 480                        NaN  Individual        Spain         NaN
# 492                        NaN  Individual        Spain         NaN
# 782                        NaN  Individual          NaN         NaN
# 791                        NaN  Individual          NaN         NaN
# 883                        NaN  Individual        Spain         NaN
#
#                                          affiliation_1 affiliation_2  \
# 111                                                NaN           NaN
# 411                                                NaN           NaN
# 480                                                NaN           NaN
# 492                                                NaN           NaN
# 782                   Madrid University, Madrid, Spain           NaN
# 791  New York University, College of Medicine, New ...           NaN
# 883                                                NaN           NaN
#
#     affiliation_3 affiliation_4         bd age_awarded
# 111           NaN           NaN 1916-05-11        73.0
# 411           NaN           NaN 1866-08-12        56.0
# 480           NaN           NaN 1832-04-19        72.0
# 492           NaN           NaN 1881-12-24        75.0
# 782           NaN           NaN 1852-05-01        54.0
# 791           NaN           NaN 1905-09-24        54.0
# 883           NaN           NaN 1898-04-26        79.0
#
# [7 rows x 54 columns]

# %%
spanish['years_since'] = current_year - spanish.awardYear
# Out:
# C:\Users\priego\AppData\Local\Temp\ipykernel_69244\3096524763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spanish['years_since'] = current_year - spanish.awardYear

# %%
spanish.years_since.min()
# Out:
# 33

# %%
spanish.sort_values('years_since')[['awardYear','category','name']]
# Out:
#      awardYear                category                    name
# 111       1989              Literature        Camilo José Cela
# 883       1977              Literature      Vicente Aleixandre
# 791       1959  Physiology or Medicine            Severo Ochoa
# 492       1956              Literature      Juan Ramón Jiménez
# 411       1922              Literature       Jacinto Benavente
# 782       1906  Physiology or Medicine  Santiago Ramón y Cajal
# 480       1904              Literature          José Echegaray

# %% [markdown]
# (7)

# %%
df['decade'] = (df.awardYear//10)*10

# %%
df[df.gender == 'female'].groupby('decade').size()
# Out:
# decade
# 1900     3
# 1910     1
# 1920     2
# 1930     3
# 1940     3
# 1960     3
# 1970     4
# 1980     4
# 1990     7
# 2000    11
# 2010    13
# dtype: int64

# %%
df.groupby(['decade','gender']).size().reset_index(name = 'count').\
    query('gender == "female"').drop(columns = 'gender').\
    rename(columns = {"count":"num_women"})
# Out:
#     decade  num_women
# 0     1900          3
# 2     1910          1
# 4     1920          2
# 6     1930          3
# 8     1940          3
# 11    1960          3
# 13    1970          4
# 15    1980          4
# 17    1990          7
# 19    2000         11
# 21    2010         13

# %%
df.groupby(['decade','gender']).size().reset_index(name = 'count').\
query('gender == "female"').reset_index(drop=True).drop(columns = 'gender').\
rename(columns = {"count":"num_women"})
# Out:
#     decade  num_women
# 0     1900          3
# 1     1910          1
# 2     1920          2
# 3     1930          3
# 4     1940          3
# 5     1960          3
# 6     1970          4
# 7     1980          4
# 8     1990          7
# 9     2000         11
# 10    2010         13

# %% [markdown]
# (8)

# %% [markdown]
# (a)

# %%
df.groupby(['awardYear','category']).size().\
reset_index(name = "num_awardees").\
    groupby('category').num_awardees.mean().\
    reset_index().\
    sort_values('num_awardees')
# Out:
#                  category  num_awardees
# 2              Literature      1.035714
# 3                   Peace      1.340000
# 1       Economic Sciences      1.647059
# 0               Chemistry      1.657658
# 4                 Physics      1.884956
# 5  Physiology or Medicine      1.990909

# %%
df.groupby(['awardYear','category']).size().\
reset_index(name = "num_awardees").\
groupby("category").num_awardees.mean()
# Out:
# category
# Chemistry                 1.657658
# Economic Sciences         1.647059
# Literature                1.035714
# Peace                     1.340000
# Physics                   1.884956
# Physiology or Medicine    1.990909
# Name: num_awardees, dtype: float64

# %%
df.groupby(['awardYear','category']).size().\
groupby('category').mean().nlargest(1).index.values[0]
# Out:
# 'Physiology or Medicine'

# %%
df.groupby(['awardYear','category']).size().reset_index(name = 'count').\
groupby('category')['count'].mean().reset_index(name = 'mean_n_awardees').\
sort_values('mean_n_awardees', ascending = False).reset_index(drop = True).iloc[0]['category']
# Out:
# 'Physiology or Medicine'

# %% [markdown]
# (b)

# %%
df.groupby(['awardYear','category']).size().reset_index(name = 'count')
# Out:
#      awardYear                category  count
# 0         1901               Chemistry      1
# 1         1901              Literature      1
# 2         1901                   Peace      2
# 3         1901                 Physics      1
# 4         1901  Physiology or Medicine      1
# ..         ...                     ...    ...
# 592       2019       Economic Sciences      3
# 593       2019              Literature      1
# 594       2019                   Peace      1
# 595       2019                 Physics      3
# 596       2019  Physiology or Medicine      3
#
# [597 rows x 3 columns]

# %%
shared_prizes = df.groupby(['awardYear','category']).size().\
reset_index(name = 'count').query('count > 1')
shared_prizes.head(10)
# Out:
#     awardYear                category  count
# 2        1901                   Peace      2
# 7        1902                   Peace      2
# 8        1902                 Physics      2
# 13       1903                 Physics      3
# 16       1904              Literature      2
# 29       1906  Physiology or Medicine      2
# 32       1907                   Peace      2
# 37       1908                   Peace      2
# 39       1908  Physiology or Medicine      2
# 42       1909                   Peace      2

# %%
shared_prizes.groupby('category').size()
# Out:
# category
# Chemistry                 48
# Economic Sciences         26
# Literature                 4
# Peace                     32
# Physics                   66
# Physiology or Medicine    71
# dtype: int64

# %%
print(shared_prizes.groupby('category').size().nlargest(1).index.values)
# Out:
# ['Physiology or Medicine']

# %%
shared_prizes.groupby('category').size()
# Out:
# category
# Chemistry                 48
# Economic Sciences         26
# Literature                 4
# Peace                     32
# Physics                   66
# Physiology or Medicine    71
# dtype: int64

# %% [markdown]
# (c)

# %%
plc = df[df.category == "Literature"].\
groupby("awardYear").filter(lambda x: len(x) > 1)
plc.name
plc.awardYear.unique()
# Out:
# array([1974, 1904, 1917, 1966], dtype=int64)

# %%
years_lit_shared = shared_prizes.query('category == "Literature"').awardYear

# %%
years_lit_shared
# Out:
# 16     1904
# 72     1917
# 280    1966
# 323    1974
# Name: awardYear, dtype: int64

# %%
df['awardYear'].isin(years_lit_shared)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: awardYear, Length: 950, dtype: bool

# %%
df[ (df['awardYear'].isin(years_lit_shared)) & (df['category'] == 'Literature')] \
[['awardYear','name','portion','motivation']].sort_values('awardYear')
# Out:
#      awardYear                name portion  \
# 259       1904    Frédéric Mistral     1/2
# 480       1904      José Echegaray     1/2
# 359       1917  Henrik Pontoppidan     1/2
# 501       1917      Karl Gjellerup     1/2
# 618       1966         Nelly Sachs     1/2
# 796       1966        Shmuel Agnon     1/2
# 237       1974      Eyvind Johnson     1/2
# 347       1974     Harry Martinson     1/2
#
#                                             motivation
# 259  in recognition of the fresh originality and tr...
# 480  in recognition of the numerous and brilliant c...
# 359  for his authentic descriptions of present-day ...
# 501  for his varied and rich poetry, which is inspi...
# 618  for her outstanding lyrical and dramatic writi...
# 796  for his profoundly characteristic narrative ar...
# 237  for a narrative art, far-seeing in lands and a...
# 347  for writings that catch the dewdrop and reflec...

# %% [markdown]
# (d)

# %%
df.groupby(["category","awardYear"]).size().\
    groupby('category').max()
# Out:
# category
# Chemistry                 3
# Economic Sciences         3
# Literature                2
# Peace                     3
# Physics                   3
# Physiology or Medicine    3
# dtype: int64

# %%
df.groupby(["category","awardYear"]).size().\
groupby('category').max()
# Out:
# category
# Chemistry                 3
# Economic Sciences         3
# Literature                2
# Peace                     3
# Physics                   3
# Physiology or Medicine    3
# dtype: int64

# %%
df.portion.unique()
# Out:
# array(['1/3', '1', '1/4', '1/2'], dtype=object)

# %%
df.groupby(['awardYear','category']).size().reset_index(name = 'count').\
groupby('category')['count'].max().reset_index(name = 'max_n_awardees').\
sort_values('max_n_awardees', ascending = False).reset_index(drop = True)
# Out:
#                  category  max_n_awardees
# 0               Chemistry               3
# 1       Economic Sciences               3
# 2                   Peace               3
# 3                 Physics               3
# 4  Physiology or Medicine               3
# 5              Literature               2

# %%
df[df.portion == '1/4'].sort_values('awardYear').head()
# Out:
#      awardYear                category  \
# 566       1903                 Physics
# 693       1903                 Physics
# 469       1946               Chemistry
# 897       1946               Chemistry
# 113       1947  Physiology or Medicine
#
#                               categoryFullName  sortOrder portion  \
# 566                 The Nobel Prize in Physics          3     1/4
# 693                 The Nobel Prize in Physics          2     1/4
# 469               The Nobel Prize in Chemistry          2     1/4
# 897               The Nobel Prize in Chemistry          3     1/4
# 113  The Nobel Prize in Physiology or Medicine          1     1/4
#
#      prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 566       141358              7795478         NaN    received
# 693       141358              7795478         NaN    received
# 469       121524              2503929         NaN    received
# 897       121524              2503929         NaN    received
# 113       146115              2914528         NaN    received
#
#                                             motivation  ...  ind_or_org  \
# 566  in recognition of the extraordinary services t...  ...  Individual
# 693  in recognition of the extraordinary services t...  ...  Individual
# 469  for their preparation of enzymes and virus pro...  ...  Individual
# 897  for their preparation of enzymes and virus pro...  ...  Individual
# 113  for their discovery of the course of the catal...  ...  Individual
#
#     residence_1  residence_2  \
# 566         NaN          NaN
# 693         NaN          NaN
# 469         NaN          NaN
# 897         NaN          NaN
# 113         NaN          NaN
#
#                                          affiliation_1 affiliation_2  \
# 566                                                NaN           NaN
# 693  École municipale de physique et de chimie indu...           NaN
# 469  Rockefeller Institute for Medical Research, Pr...           NaN
# 897  Rockefeller Institute for Medical Research, Pr...           NaN
# 113          Washington University, St. Louis, MO, USA           NaN
#
#     affiliation_3 affiliation_4         bd age_awarded decade
# 566           NaN           NaN 1867-11-07        36.0   1900
# 693           NaN           NaN 1859-05-15        44.0   1900
# 469           NaN           NaN 1891-07-05        55.0   1940
# 897           NaN           NaN 1904-08-16        42.0   1940
# 113           NaN           NaN 1896-12-05        51.0   1940
#
# [5 rows x 55 columns]

# %%
df.query('awardYear == 1903 & category == "Physics"')
# Out:
#      awardYear category            categoryFullName  sortOrder portion  \
# 354       1903  Physics  The Nobel Prize in Physics          1     1/2
# 566       1903  Physics  The Nobel Prize in Physics          3     1/4
# 693       1903  Physics  The Nobel Prize in Physics          2     1/4
#
#      prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 354       141358              7795478         NaN    received
# 566       141358              7795478         NaN    received
# 693       141358              7795478         NaN    received
#
#                                             motivation  ...  ind_or_org  \
# 354  in recognition of the extraordinary services h...  ...  Individual
# 566  in recognition of the extraordinary services t...  ...  Individual
# 693  in recognition of the extraordinary services t...  ...  Individual
#
#     residence_1  residence_2  \
# 354         NaN          NaN
# 566         NaN          NaN
# 693         NaN          NaN
#
#                                          affiliation_1 affiliation_2  \
# 354                 École Polytechnique, Paris, France           NaN
# 566                                                NaN           NaN
# 693  École municipale de physique et de chimie indu...           NaN
#
#     affiliation_3 affiliation_4         bd age_awarded decade
# 354           NaN           NaN 1852-12-15        51.0   1900
# 566           NaN           NaN 1867-11-07        36.0   1900
# 693           NaN           NaN 1859-05-15        44.0   1900
#
# [3 rows x 55 columns]

# %%
mot = df.query('awardYear == 1903 & category == "Physics"').reset_index()['motivation']
print(mot.iloc[1] == mot.iloc[2])
print(mot.iloc[0] == mot.iloc[1])
# Out:
# True
# False

# %%
print("huhuhuh")
